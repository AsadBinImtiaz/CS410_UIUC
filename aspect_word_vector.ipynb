# %%
# imports needed libs
import gensim 
import pandas as pd
import pickle
import itertools
import spacy
import time

# %%
nlp = spacy.load('en_core_web_sm', disable=["ner"])

# %%
def read_topic_data():
    return pd.read_csv('processed_data/cleaned_reviews.csv', usecols = ["business_id", "name", "review_id","text","topic_text","sentiment_text","review_stars"])

# %%
data = read_topic_data()

# %%
stop_words = [line.rstrip('\n') for line in open('config/stopwords.txt', 'r', encoding='utf-8')] 
neg_words  = [line.rstrip('\n') for line in open('config/negations.txt', 'r', encoding='utf-8')]
stopwords = stop_words + neg_words

# %%
def list_diff(list1,list2):
    return list(itertools.filterfalse(set(list2).__contains__, list1))

# %%
def split_phrases(str_list):
    new_list = []
    for tok in str_list:
        if '-' in tok:
            new_list += tok.split('-')
        new_list.append(tok)
    return list_diff(new_list,stop_words)

# %%
topic_set = [split_phrases((u''+str(txt)).replace('.','').split()) for txt in data.topic_text]

# %%
senti_set = [split_phrases((u''+str(txt)).replace('.','').split()) for txt in data.sentiment_text]

# %%
# %%time
#build vocabulary and train model
topic_model = gensim.models.Word2Vec(
        topic_set,
        size=100,
        window=10,
        min_count=100,
        workers=100,
        iter=10)

#  Stats
## NC (0250 MB): Wall time:   14.8 s /   22 s
## ALL         : 4min 34s

# %%
# %%time
#build vocabulary and train model
senti_model = gensim.models.Word2Vec(
        senti_set,
        size=100,
        window=15,
        min_count=100,
        workers=100,
        iter=20)

#  Stats
## NC (0250 MB): Wall time:   14.8 s /   22 s
## ALL         : Wall time: 17min 19s

# %%
#with open('pickles/aspect_topic_model.pk', 'wb') as fin:
#    pickle.dump(topic_model, fin)
#with open('pickles/aspect_senti_model.pk', 'wb') as fin:
#    pickle.dump(senti_model, fin)

# %%
senti_model = None
topic_model = None
with open('pickles/aspect_topic_model.pk', 'rb') as fin:
    topic_model = pickle.load(fin)
with open('pickles/aspect_senti_model.pk', 'rb') as fin:
    senti_model = pickle.load(fin)

# %%
topic_model.wv.most_similar(positive='cusine',topn=5)
# Out:
# [('cuisine', 0.7098367810249329),
#  ('thailand', 0.6114474534988403),
#  ('laos', 0.607699453830719),
#  ('authenticity', 0.5937446355819702),
#  ('region', 0.5881584882736206)]

# %%
senti_model.wv.most_similar(positive='far',topn=2)
# Out:
# [('superior-food', 0.6407245397567749),
#  ('superior-service', 0.5888615846633911)]

# %%
senti_model.wv.similarity(w1='location',w2='far')
# Out:
# 0.22458847

# %%
senti_model.wv.similarity(w1='staff',w2='far')
# Out:
# 0.016833797

# %%
senti_model.wv.similarity(w1='atmosphere',w2='far')
# Out:
# 0.0422838

# %%
senti_model.wv.similarity(w1='price',w2='far')
# Out:
# 0.05009885

# %%
senti_model.wv.similarity(w1='service',w2='far')
# Out:
# 0.073056154

# %%
Aspect_Terms = ['food','service','staff','location','value']

# %%
def get_all_topics_map():
    with open('config/all_topics.txt', 'r') as f:
         ret = {line.split(';')[0]: line.split(';')[1].replace('\n','') for line in f.readlines()}
    return ret

# %%
topic_map = get_all_topics_map()

# %%
vocab = []
for x in topic_map.values():
    for y in x.split('/'):
        vocab.append(y)

# %%
def get_aspect_map():
    with open('config/aspect_map.txt', 'r') as f:
        ret = {line.split(';')[0]: line.split(';')[1].replace('\n','') for line in f.readlines()}
    return ret

# %%
aspect_map = get_aspect_map()

# %%
aspect_map.keys()
# Out:
# dict_keys(['food', 'atmosphere', 'staff', 'value', 'cent', 'location', 'appetizer', 'area', 'attentive', 'bacon', 'bar', 'bartender', 'beer', 'bill', 'bland', 'bread', 'breakfast', 'brunch', 'buffet', 'burger', 'burrito', 'caesar', 'charge', 'check', 'cheese', 'chef', 'chicken', 'clean', 'coffee', 'cook', 'couple', 'crust', 'customer', 'service', 'delicious', 'dessert', 'dinner', 'dish', 'dollar', 'dress', 'drink', 'drive', 'employee', 'fast', 'fish', 'flavor', 'friendly', 'friendly-staff', 'great-atmosphere', 'great-customer', 'great-food', 'great-service', 'grill', 'happy-hour', 'helpful', 'hotel', 'hour', 'inside', 'lobster', 'lunch', 'manager', 'meal', 'meat', 'minute', 'noodle', 'not-wait', 'offer', 'option', 'outside', 'pancake', 'pasta', 'people', 'pizza', 'portion', 'price', 'bad', 'overprice', 'money', 'quality', 'refill', 'reservation', 'review', 'selection', 'server', 'slow', 'special', 'star', 'street', 'tasty', 'town', 'parking', 'kitchen', 'table', 'chair', 'vegas', 'visit', 'wait', 'waiter', 'wine', 'wing', 'yummy', 'job', 'place', 'door', 'Ingredient', 'lady', 'attitude', 'ambience', 'environment', 'rude', 'toilet', 'washroom', 'city', 'downtown'])

# %%
def assign_aspect(sent,aspect_map):
    dicty = {}
    
    for word in nlp(sent.lower()):
        if word.lemma_ not in stopwords:
            score = 0
            aspec = None
            for asp in aspect_map.keys():
                try:
                    sco = senti_model.wv.similarity(w1=asp,w2=word.lemma_)
                    if sco > score:
                        score=sco
                        aspec=asp
                        dicty[aspec]= dicty.setdefault(asp, 0) + score    
                except:
                    continue
            
    if len(dicty)==0:
        return None
    
    ret = max(dicty.items(), key=lambda k: k[1])
    if ret[1]<0.3:
        return None
    
    return aspect_map[ret[0]]

# %%
# %%time
lst = []
start = time.time()
end = time.time()
total = len(data)
for index,txt in enumerate(data.text):
    mydict = {}
    for w in Aspect_Terms:
        mydict[w] = mydict.setdefault(w, '')  
    for x in txt.replace('\\n','.').replace('\n','.').split('.'):
        if(len(x)>0):
            y = assign_aspect(x,aspect_map)
            mydict[y] = mydict.setdefault(y, '') + x +'.\n' 
    mydict.pop(None, None)
    lst.append(mydict)
    
    if index%1000 == 0 and index > 0:
        print(f".", end='')
            
    if index%10000 == 0 and index > 0:
        end = time.time()
        print(f' Clustered [{index+1:>{5}}/{total:>{5}} ] - {str(end-start):>{9.6}} secs')
        start = time.time()
        with open('pickles/IL/'+str(index)+'.pk', 'wb') as fin:
            pickle.dump(lst, fin)
        lst = []
        
print(f'\n Clustered [{total:>{5}} ] - {str(end-start):>{9.6}} secs')

with open('pickles/IL/3530000.pk', 'wb') as fin:
    pickle.dump(lst, fin)
# Out:
# ........... Clustered [10001/3527902 ] -    877.50 secs
# .......... Clustered [20001/3527902 ] -    884.31 secs
# .......... Clustered [30001/3527902 ] -    861.31 secs
# .......... Clustered [40001/3527902 ] -    915.41 secs
# .......... Clustered [50001/3527902 ] -    964.49 secs
# .......... Clustered [60001/3527902 ] -    985.38 secs
# .......... Clustered [70001/3527902 ] -    853.13 secs
# .......... Clustered [80001/3527902 ] -    9260.8 secs
# .......... Clustered [90001/3527902 ] -    820.37 secs
# .......... Clustered [100001/3527902 ] -    877.12 secs
# .......... Clustered [110001/3527902 ] -    778.26 secs
# .......... Clustered [120001/3527902 ] -    849.11 secs
# .......... Clustered [130001/3527902 ] -    973.29 secs
# .......... Clustered [140001/3527902 ] -    902.66 secs
# .......... Clustered [150001/3527902 ] -    867.14 secs
# .......... Clustered [160001/3527902 ] -    911.16 secs
# .......... Clustered [170001/3527902 ] -    884.26 secs
# .......... Clustered [180001/3527902 ] -    929.08 secs
# .......... Clustered [190001/3527902 ] -    900.69 secs
# .......... Clustered [200001/3527902 ] -    917.70 secs
# .......... Clustered [210001/3527902 ] -    897.86 secs
# .......... Clustered [220001/3527902 ] -    828.51 secs
# .......... Clustered [230001/3527902 ] -    880.13 secs
# .......... Clustered [240001/3527902 ] -    933.06 secs
# .......... Clustered [250001/3527902 ] -    909.84 secs
# .......... Clustered [260001/3527902 ] -    908.05 secs
# .......... Clustered [270001/3527902 ] -    886.96 secs
# .......... Clustered [280001/3527902 ] -    921.67 secs
# .......... Clustered [290001/3527902 ] -    983.15 secs
# .......... Clustered [300001/3527902 ] -    931.23 secs
# .......... Clustered [310001/3527902 ] -    947.68 secs
# .......... Clustered [320001/3527902 ] -    991.52 secs
# .......... Clustered [330001/3527902 ] -    976.90 secs
# .......... Clustered [340001/3527902 ] -    940.97 secs
# .......... Clustered [350001/3527902 ] -    925.29 secs
# .......... Clustered [360001/3527902 ] -    925.40 secs
# .......... Clustered [370001/3527902 ] -    929.22 secs
# .......... Clustered [380001/3527902 ] -    974.40 secs
# .......... Clustered [390001/3527902 ] -    934.23 secs
# .......... Clustered [400001/3527902 ] -    991.22 secs
# .......... Clustered [410001/3527902 ] -    952.80 secs
# .......... Clustered [420001/3527902 ] -    1017.0 secs
# .......... Clustered [430001/3527902 ] -    1006.9 secs
# .......... Clustered [440001/3527902 ] -    1116.1 secs
# .......... Clustered [450001/3527902 ] -    1043.0 secs
# .......... Clustered [460001/3527902 ] -    1041.1 secs
# .......... Clustered [470001/3527902 ] -    986.25 secs
# .......... Clustered [480001/3527902 ] -    980.97 secs
# .......... Clustered [490001/3527902 ] -    17172. secs
# .......... Clustered [500001/3527902 ] -    984.00 secs
# .......... Clustered [510001/3527902 ] -    1062.3 secs
# .......... Clustered [520001/3527902 ] -    1016.2 secs
# .......... Clustered [530001/3527902 ] -    1129.4 secs
# .......... Clustered [540001/3527902 ] -    958.53 secs
# .......... Clustered [550001/3527902 ] -    971.99 secs
# .......... Clustered [560001/3527902 ] -    1103.4 secs
# .......... Clustered [570001/3527902 ] -    1159.0 secs
# .......... Clustered [580001/3527902 ] -    1097.3 secs
# .......... Clustered [590001/3527902 ] -    1091.3 secs
# .......... Clustered [600001/3527902 ] -    1071.7 secs
# .......... Clustered [610001/3527902 ] -    1234.4 secs
# .......... Clustered [620001/3527902 ] -    1463.6 secs
# .......... Clustered [630001/3527902 ] -    1214.2 secs
# .......... Clustered [640001/3527902 ] -    1089.1 secs
# .......... Clustered [650001/3527902 ] -    1383.7 secs
# .......... Clustered [660001/3527902 ] -    1128.7 secs
# .......... Clustered [670001/3527902 ] -    1140.3 secs
# .......... Clustered [680001/3527902 ] -    1163.4 secs
# .......... Clustered [690001/3527902 ] -    6996.9 secs
# .......... Clustered [700001/3527902 ] -    1258.0 secs
# .......... Clustered [710001/3527902 ] -    1243.2 secs
# .......... Clustered [720001/3527902 ] -    1303.0 secs
# .......... Clustered [730001/3527902 ] -    2118.1 secs
# .......... Clustered [740001/3527902 ] -    1294.6 secs
# .......... Clustered [750001/3527902 ] -    1271.1 secs
# .......... Clustered [760001/3527902 ] -    1353.5 secs
# .......... Clustered [770001/3527902 ] -    1348.7 secs
# .......... Clustered [780001/3527902 ] -    1406.0 secs
# .......... Clustered [790001/3527902 ] -    1334.9 secs
# .......... Clustered [800001/3527902 ] -    1350.0 secs
# .......... Clustered [810001/3527902 ] -    1325.2 secs
# .......... Clustered [820001/3527902 ] -    1368.3 secs
# .......... Clustered [830001/3527902 ] -    1413.3 secs
# .......... Clustered [840001/3527902 ] -    1403.6 secs
# .......... Clustered [850001/3527902 ] -    1454.4 secs
# .......... Clustered [860001/3527902 ] -    1403.3 secs
# .......... Clustered [870001/3527902 ] -    1448.1 secs
# .......... Clustered [880001/3527902 ] -    1560.9 secs
# .......... Clustered [890001/3527902 ] -    1527.2 secs
# .......... Clustered [900001/3527902 ] -    1295.0 secs
# .......... Clustered [910001/3527902 ] -    1423.3 secs
# .......... Clustered [920001/3527902 ] -    1362.7 secs
# .......... Clustered [930001/3527902 ] -    1431.3 secs
# .......... Clustered [940001/3527902 ] -    1478.4 secs
# .......... Clustered [950001/3527902 ] -    1425.0 secs
# .......... Clustered [960001/3527902 ] -    1462.2 secs
# .......... Clustered [970001/3527902 ] -    1442.0 secs
# .......... Clustered [980001/3527902 ] -    1502.5 secs
# .......... Clustered [990001/3527902 ] -    19984. secs
# .......... Clustered [1000001/3527902 ] -    1555.0 secs
# .......... Clustered [1010001/3527902 ] -    1347.6 secs
# .......... Clustered [1020001/3527902 ] -    1579.3 secs
# .......... Clustered [1030001/3527902 ] -    1529.7 secs
# .......... Clustered [1040001/3527902 ] -    1534.7 secs
# .......... Clustered [1050001/3527902 ] -    1569.0 secs
# .......... Clustered [1060001/3527902 ] -    1546.8 secs
# .......... Clustered [1070001/3527902 ] -    1609.8 secs
# ......

# %%
lst = []
for index in range(len(data)):
    if index%10000 == 0 and index > 0:
        with open('pickles/IL/'+str(index)+'.pk', 'rb') as fin:
            lst += pickle.load(fin)
        print(index)
with open('pickles/IL/3530000.pk', 'rb') as fin:
    lst += pickle.load(fin)

# %%
aspect_df = pd.DataFrame(lst)

# %%
aspect_df
# Out:
#                                               atmosphere  \
# 0                                                    NaN
# 1       I quietly walked back to my seat to retrieve ...
# 2                                                    NaN
# 3      It's impressive how filthy this place is.\n So...
# 4                                                    NaN
# 5                                                    NaN
# 6       I have no idea what sort of food was being pr...
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                Nothing really fun about this place.\n
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17     While I was there I walked into the bathroom a...
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23      If you have that as your mindset, you won't n...
# 24                                                   NaN
# 25                                                   NaN
# 26      I've only come here when I'm craving Chinese,...
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 19190   Just wish the basement was open more, it's od...
# 19191                                                NaN
# 19192   It was clean, but I guess I hope for personal...
# 19193                                                NaN
# 19194   the place is clean and there is ample room an...
# 19195          I'm not sure what it is, but it's just.\n
# 19196   Hopefully if customers are complaining about ...
# 19197   On this particular Thursday, that is exactly ...
# 19198   But, there is a great space downstairs that i...
# 19199   Lots of TV's around the bar area.\nSummertime...
# 19200                                                NaN
# 19201   I still go along, but my heels drag on the wa...
# 19202                                                NaN
# 19203                                                NaN
# 19204                                                NaN
# 19205                                                NaN
# 19206  Everything else about this place kinda fades i...
# 19207    I take customers and job interviewees here a...
# 19208                                                NaN
# 19209                                                NaN
# 19210                                                NaN
# 19211   Haven't heard back from anyone and it's been ...
# 19212                                                NaN
# 19213   After a bad experience at the business, the m...
# 19214                                                NaN
# 19215                                                NaN
# 19216                                                NaN
# 19217                                                NaN
# 19218                                                NaN
# 19219                                                NaN
#
#                                                     food  \
# 0       This is a disgusting restaurant.\n You can fi...
# 1       Before I picked up a plate to start in on the...
# 2      The best food I want to the a lot of the buffe...
# 3       The only worthwhile feature is that the food ...
# 4        And they suggested that I try this buffet.\n...
# 5      absolutely disgusting.\n arrived for lunch on ...
# 6       I was hungry and against my better judgement ...
# 7      It is a Chinese buffet!! They have a lot of su...
# 8      Not necessarily the best Chinese food in town,...
# 9                             My friend took me there.\n
# 10      If you are looking for some gourmet Chinese f...
# 11      But it did what it was supposed to which was ...
# 12     Good food east side of building  outside is ab...
# 13     Kinda just "meh".\n They need to change the fo...
# 14     While the price may be a little steep dependin...
# 15     Came here for Valentines Day when it was busy,...
# 16     I would give them more stars the food is great...
# 17     Went there last night for a family dinner.\n T...
# 18     This is not the worst Chinese buffet I've ever...
# 19     I have had my fair share of Chinese buffet.\n ...
# 20     Food was very good! Also very fresh!! The staf...
# 21     My husband likes it because there is a lot of ...
# 22     As far as cleanliness, choices and prices, thi...
# 23     In general, I am not a fan of Chinese buffets....
# 24     Had lunch here thje other day.\n Lots of buffe...
# 25     like seriously first of all I'm not small I lo...
# 26
# 27     Why are you reading reviews of a buffet? There...
# 28
# 29      I spent the longest time walking around with ...
# ...                                                  ...
# 19190  Friendly staff, good bar food and great drank ...
# 19191  I have been here twice on a Monday afternoon a...
# 19192  Food: Ordered a Prime Rib Sandwich, and by no ...
# 19193  I've had a mix of experiences here but one thi...
# 19194   A good place to eat and drink likely on the w...
# 19195  Decent food and service, but I can honestly sa...
# 19196
# 19197  Over the course of a week, there comes a time ...
# 19198   But please, indulge in the quesadillas, tiny ...
# 19199  Great place for eating and enjoying some reall...
# 19200  In general, I like Guidos.\n  I think their fo...
# 19201   If friends suggest Guido's, which they often ...
# 19202  The food is very good, but I've been to lunch ...
# 19203  I like their decor, and I like their onion rin...
# 19204   Of course many other reviewers make good poin...
# 19205  This is not a place to write home about for th...
# 19206  What comes to mind when I think of Guido's? Th...
# 19207  Outstanding food for the price, but the staff ...
# 19208                       Food just never up to par.\n
# 19209  Very disappointing tonight.\n I know it's pub ...
# 19210  Had a grilled ham & cheese sandwich that was g...
# 19211
# 19212  Guido's is ok.\nPros: great burgers (even the ...
# 19213
# 19214   It's great for our friends and my wife becaus...
# 19215  The burgers are good! They claim double patty ...
# 19216  It did have one good experience, but last nigh...
# 19217  The food is fantastic for the price, especiall...
# 19218   We had a wonderful dinner.\n It is basic bar ...
# 19219    But a hamburger order plus 3 club sandwiches...
#
#                                                 location  \
# 0
# 1       I will be calling the Champaign-Urbana Public...
# 2
# 3
# 4      I was visiting the Champaign area with my fami...
# 5
# 6      Another restaurants make the DNV list in Champ...
# 7      They have a wide range of things to eat and th...
# 8
# 9
# 10                       STAY AWAY OF THIS PLACE!!!!!.\n
# 11
# 12
# 13      Looks run down from the outside.\n Would reco...
# 14
# 15
# 16
# 17
# 18
# 19      Over the last four years, I went to this rest...
# 20      They could cut in front of you and stand righ...
# 21       Oh, and I do like "fried biscuits" the donut...
# 22
# 23
# 24      The outside needs attention, and the restroom...
# 25
# 26     Not the best Chinese in town, but I think my p...
# 27
# 28
# 29      The Chinese restaurant life has been my famil...
# ...                                                  ...
# 19190   Awesome patio, especially for solar eclipses....
# 19191   But, I also got a ticket while parked in the ...
# 19192  Ambiance: Guido's seems to be more of a sports...
# 19193   And there's ample seating! One of my downtown...
# 19194  An overall pretty good bar in downtown Champai...
# 19195
# 19196
# 19197   We typically go for our favorite restaurants ...
# 19198  This is a bar that i have been to a lot of net...
# 19199
# 19200  Overall, I like going there to play pool on th...
# 19201  There are a million places just like Guido's o...
# 19202
# 19203
# 19204  If you are in the mood for nachos, head here.\...
# 19205    Obviously I could only remember the ones tha...
# 19206
# 19207                        Best onion rings in town.\n
# 19208   Walk across the street to try something else....
# 19209   Grateful that we have plenty of better option...
# 19210   Sat at the bar and service was pretty poor co...
# 19211
# 19212  Cons: Downstairs club gets a bit rough later o...
# 19213   The hand written letter is most impressive of...
# 19214  I keep coming back over and over for a good dr...
# 19215
# 19216   Entered, sat down to eat.\n A bar tender and ...
# 19217  During the day it has a nice, laid-back atmosp...
# 19218
# 19219                             A bar with bar food.\n
#
#                                                  service  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6       It was a weeknight so luckily there was no li...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15     Come here when it's busy, and you won't be dis...
# 16     im sorry but who wants to be waited on as soon...
# 17      You have to chase down a server to get a drin...
# 18
# 19
# 20                    We never got a refill on drinks.\n
# 21
# 22
# 23
# 24                                    very poor shape.\n
# 25
# 26
# 27
# 28
# 29     Walked in, not greeted, was asked "How many" a...
# ...                                                  ...
# 19190                            Can spend hours here.\n
# 19191
# 19192   She refilled my water, made sure my food came...
# 19193
# 19194
# 19195
# 19196
# 19197  I am the type of person that usually is able t...
# 19198   I have not come to this restaurant and sat up...
# 19199
# 19200
# 19201   The place gets pretty crowded on Thurs-Sat ni...
# 19202    Slow service, screwed up orders, slow to get...
# 19203    It seriously took 10 minutes between being s...
# 19204
# 19205
# 19206                      But seriously - who cares?.\n
# 19207
# 19208
# 19209
# 19210
# 19211            very dishonest, questionable service.\n
# 19212  sides (ESP fruit and veges) on sandwiches not ...
# 19213
# 19214
# 19215   If you want decent service, make sure to be a...
# 19216
# 19217  I go to Guido's occasionally and always have a...
# 19218                   And the service was very good.\n
# 19219    A projected 60 minute wait lasted 40.\n  Had...
#
#                                                    staff  \
# 0       This restaurant should really be inspected by...
# 1       I alerted a waitress, who acted as if it was ...
# 2
# 3       You would think the staff would pick up trash...
# 4
# 5
# 6       Even the water that they were boiled in looke...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14      The manager is also extremely unprofessional ...
# 15
# 16
# 17      Makes me wonder if the employees ever wash th...
# 18
# 19                       Horrible, slam dunk horrible.\n
# 20
# 21
# 22      Our waitress was very sweet as well.\n We did...
# 23
# 24
# 25
# 26
# 27
# 28     Rude came in8:45 close at 9 told us we could e...
# 29     Short answer: Avoid this place.\n Waitress did...
# ...                                                  ...
# 19190
# 19191
# 19192   I'd guess it was a cut of ribeye, but it was ...
# 19193
# 19194
# 19195
# 19196   Yea thanks already knew that.\n Offered no ap...
# 19197
# 19198  The bartenders are always very friendly and ni...
# 19199
# 19200  The bartenders have always been very nice, but...
# 19201
# 19202                  everybody, management included.\n
# 19203    It was one of those non-busy times when ther...
# 19204
# 19205
# 19206                                    End of story.\n
# 19207
# 19208
# 19209
# 19210
# 19211   Was charged for 16 drinks - asked to speak wi...
# 19212
# 19213
# 19214
# 19215
# 19216   We sat and stared in their direction and noth...
# 19217
# 19218
# 19219                        Wait staff was oblivious.\n
#
#                                                    value
# 0      I would have given this restaurant zero stars ...
# 1
# 2
# 3       The quality ranges from poor to mediocre.\n I...
# 4
# 5       this is by far the worst sushi I have ever se...
# 6      Restaurant review:.\n This is bad news.\n Okay...
# 7      I was looking for reviews and I saw how bad th...
# 8
# 9       Price was ok.\n Everything is just within the...
# 10     The worst buffet I've ever had.\n Not worth of...
# 11
# 12
# 13            Nothing really special about this place.\n
# 14      I just can't shake the substandard health sta...
# 15
# 16     so heres a tip if your reading this yall bette...
# 17      I use to really like this place but over the ...
# 18
# 19      This was definitely the worst among all.\n Ea...
# 20
# 21
# 22      However, we brought a coupon that we printed ...
# 23      There's plenty of seating here and you genera...
# 24
# 25     It's my favorite place to eat other then the f...
# 26      Therefore, I appreciate the decent selection ...
# 27
# 28
# 29     Not trying to tear down this restaurant becaus...
# ...                                                  ...
# 19190
# 19191   However, I am not that impressed with anythin...
# 19192
# 19193
# 19194
# 19195   In fact, I only go here when the rest of the ...
# 19196  Owner reached out to me after I wrote this rev...
# 19197
# 19198
# 19199     Almost forgot to speak of their milk shakes.\n
# 19200    They have a good selection of bottled beer, ...
# 19201  Going a few more times since last review, I th...
# 19202
# 19203  Other than that, I was just not impressed.\n  ...
# 19204
# 19205    I dont remember them all but Tuesdays are 4 ...
# 19206
# 19207
# 19208
# 19209   I wouldn't even have minded this if we had be...
# 19210
# 19211  Do not open a tab here.\n I came in two days l...
# 19212
# 19213  I am very impressed.\n With a coupon and a han...
# 19214  They do both very well and at a reasonable pri...
# 19215
# 19216   The only reason I am giving it one star is be...
# 19217
# 19218  The management went out of their way to make u...
# 19219
#
# [19220 rows x 6 columns]

# %%
aspects_df = data[['review_id','text','review_stars']]

# %%
for asp in Aspect_Terms:
    aspects_df[asp] = aspect_df[asp]

# %%
aspects_df
# Out:
#                     review_id  \
# 0      8MTptiOpUeuPUFZgtfk9Vw
# 1      ofpfzn8LV4nJ2pE6IlTVdg
# 2      O3yApCw95tbA0kodflQrpA
# 3      fFTVZE7EENdl66SX9cgc0A
# 4      pDlIw6DLLjZ5G1vJnMzr9A
# 5      xwJizYjeafDbsJVmPmBSgQ
# 6      mvAvUVOkSuEr6EHZ97sg0Q
# 7      ticGaTnIjhkijFqWmww5uw
# 8      4ftuoeacaUQ1EyiW_xt1QA
# 9      aDCXNKvZpoD9s4GICWdqUg
# 10     r-4_NT2Ko232o2jb57xamQ
# 11     yLwPBITQnIe3MMU6Gkm1Tw
# 12     wRfxg0eGbauSElkZy4AObQ
# 13     QDaM70gzI4XLZFHrPffDVA
# 14     JTISByuUwaZwfmTH2nLVLQ
# 15     tBmosR1h73EC3zkbztkZ4Q
# 16     TlUl5Mp7DXMLp9oCvsu_9g
# 17     ca3Weqo3gE5BfWySyYyYqw
# 18     85JphyjHRvq9SsEz5Q7e2A
# 19     t1Rm0I05qmAdYSWfQwsmHg
# 20     qsLHeRDEq9E_Cj-Bz_59qQ
# 21     K6J0JPnPoEdbDPeRmfBbxw
# 22     YpzcpYhvMopaCrVcnAmQSQ
# 23     ucKQ8OeJyZlLeyhruHM3bQ
# 24     6Hhm7bjMyZecqU5kZZIyBQ
# 25     nfIH54SxLB77fcQpFTKbOw
# 26     x3b3EsZJEhhSjsz8abD8fQ
# 27     Sp82eEDhnOivtxKSQFfAIA
# 28     wKa4a-vfzH_I7-joGAhLFw
# 29     jFlrexBLigmpybhXcqtGzA
# ...                       ...
# 19190  qCX-c0kPNh2Up9CpJkZLow
# 19191  1KbcRXRxMZ4x89HYMTCACw
# 19192  HYIFnjHnFRykeMS6cdP95g
# 19193  W2NtkgFFYuC3uYvieFNzSg
# 19194  mRtHozxg42Uxxi3zmKynYA
# 19195  _DQzRTv2kR9l9pYyI2_eBA
# 19196  sbmErmzLymQs-pMqsJg6MQ
# 19197  512VpYv0w5OFgwJoFVCc8Q
# 19198  NwzSuCpvTEn9hcFbv7nzGw
# 19199  7ksbP0FSK2RB4kpQuXndvA
# 19200  mruCbb3pjDxy7Zy6ybJMTg
# 19201  X5vbDohuLAZ4Jl_gkapiHA
# 19202  3QkKg1yTovNtlL-T6Qv5UQ
# 19203  GrW96p-AjJWYN7TWF05pbw
# 19204  mTWz1did2_9yPfzqbuKn_w
# 19205  q7LlT84AkXJwoadj_fslCg
# 19206  ibm1FOvNxkytJbIF2nzDSw
# 19207  GosGbgFc6ua_IClskgLG7Q
# 19208  ic1hB_83A0Pwa8aeU-N1QA
# 19209  llINukf2uGHLm0LW-yKbIA
# 19210  RWJwyzSInsGEmXfeo0GfLA
# 19211  Qir-QA3QA_djQVFfiWbIFA
# 19212  wUQngfXMmiSaGTKbjrhowg
# 19213  refeAKpRj7EQfU2eIvIFJQ
# 19214  ZGTjk4wT7FbKa5UdYRSmLg
# 19215  8ePzpg9tHddHi9WMKehrAA
# 19216  5GCqbhpFF_omSFsYxbRVUg
# 19217  sVztDMZzAsAP-4qTATTF2A
# 19218  HuuKbMdougFJwvZ8H8Pz9g
# 19219  FeudNHXnbF5LCedgZLJdeQ
#
#                                                     text  review_stars  \
# 0      I would have given this restaurant zero stars ...           1.0
# 1      So...no. Just...no. Before I picked up a plate...           1.0
# 2      The best food I want to the a lot of the buffe...           5.0
# 3      It's impressive how filthy this place is. Some...           1.0
# 4      I was visiting the Champaign area with my fami...           5.0
# 5      absolutely disgusting. arrived for lunch on a ...           1.0
# 6      Restaurant review:\nAnother restaurants make t...           1.0
# 7      I was looking for reviews and I saw how bad th...           5.0
# 8      Not necessarily the best Chinese food in town,...           4.0
# 9      My friend took me there. Price was ok. Everyth...           3.0
# 10     The worst buffet I've ever had. Not worth of t...           1.0
# 11     This place was just ok. But it did what it was...           3.0
# 12     Good food east side of building  outside is ab...           1.0
# 13     Kinda just "meh". Nothing really fun about thi...           2.0
# 14     While the price may be a little steep dependin...           2.0
# 15     Came here for Valentines Day when it was busy,...           5.0
# 16     I would give them more stars the food is great...           3.0
# 17     Went there last night for a family dinner. I u...           1.0
# 18     This is not the worst Chinese buffet I've ever...           2.0
# 19     I have had my fair share of Chinese buffet. Th...           1.0
# 20     Food was very good! Also very fresh!! The staf...           4.0
# 21     My husband likes it because there is a lot of ...           2.0
# 22     As far as cleanliness, choices and prices, thi...           2.0
# 23     In general, I am not a fan of Chinese buffets....           3.0
# 24     Had lunch here thje other day. Lots of buffet ...           2.0
# 25     It's my favorite place to eat other then the f...           3.0
# 26     Not the best Chinese in town, but I think my p...           4.0
# 27     Why are you reading reviews of a buffet? There...           3.0
# 28     Rude came in8:45 close at 9 told us we could e...           1.0
# 29     Short answer: Avoid this place. The Chinese re...           1.0
# ...                                                  ...           ...
# 19190  Friendly staff, good bar food and great drank ...           5.0
# 19191  I have been here twice on a Monday afternoon a...           3.0
# 19192  Food: Ordered a Prime Rib Sandwich, and by no ...           4.0
# 19193  I've had a mix of experiences here but one thi...           4.0
# 19194  An overall pretty good bar in downtown Champai...           4.0
# 19195  Decent food and service, but I can honestly sa...           2.0
# 19196  Owner reached out to me after I wrote this rev...           1.0
# 19197  Over the course of a week, there comes a time ...           2.0
# 19198  This is a bar that i have been to a lot of net...           4.0
# 19199  Great place for eating and enjoying some reall...           5.0
# 19200  In general, I like Guidos.  They have a good s...           3.0
# 19201  Going a few more times since last review, I th...           2.0
# 19202  The food is very good, but I've been to lunch ...           2.0
# 19203  I like their decor, and I like their onion rin...           2.0
# 19204  If you are in the mood for nachos, head here. ...           3.0
# 19205  This is not a place to write home about for th...           3.0
# 19206  What comes to mind when I think of Guido's? Th...           4.0
# 19207  Outstanding food for the price, but the staff ...           4.0
# 19208  Food just never up to par. Walk across the str...           2.0
# 19209  Very disappointing tonight. I know it's pub fo...           1.0
# 19210  Had a grilled ham & cheese sandwich that was g...           3.0
# 19211  Do not open a tab here.. very dishonest, quest...           1.0
# 19212  Guido's is ok. \nPros: great burgers (even the...           3.0
# 19213  I am very impressed. After a bad experience at...           5.0
# 19214  I keep coming back over and over for a good dr...           5.0
# 19215  The burgers are good! They claim double patty ...           2.0
# 19216  It did have one good experience, but last nigh...           1.0
# 19217  I go to Guido's occasionally and always have a...           5.0
# 19218  The management went out of their way to make u...           5.0
# 19219  A bar with bar food.  There were four of us.  ...           1.0
#
#                                                     food  \
# 0       This is a disgusting restaurant.\n You can fi...
# 1       Before I picked up a plate to start in on the...
# 2      The best food I want to the a lot of the buffe...
# 3       The only worthwhile feature is that the food ...
# 4        And they suggested that I try this buffet.\n...
# 5      absolutely disgusting.\n arrived for lunch on ...
# 6       I was hungry and against my better judgement ...
# 7      It is a Chinese buffet!! They have a lot of su...
# 8      Not necessarily the best Chinese food in town,...
# 9                             My friend took me there.\n
# 10      If you are looking for some gourmet Chinese f...
# 11      But it did what it was supposed to which was ...
# 12     Good food east side of building  outside is ab...
# 13     Kinda just "meh".\n They need to change the fo...
# 14     While the price may be a little steep dependin...
# 15     Came here for Valentines Day when it was busy,...
# 16     I would give them more stars the food is great...
# 17     Went there last night for a family dinner.\n T...
# 18     This is not the worst Chinese buffet I've ever...
# 19     I have had my fair share of Chinese buffet.\n ...
# 20     Food was very good! Also very fresh!! The staf...
# 21     My husband likes it because there is a lot of ...
# 22     As far as cleanliness, choices and prices, thi...
# 23     In general, I am not a fan of Chinese buffets....
# 24     Had lunch here thje other day.\n Lots of buffe...
# 25     like seriously first of all I'm not small I lo...
# 26
# 27     Why are you reading reviews of a buffet? There...
# 28
# 29      I spent the longest time walking around with ...
# ...                                                  ...
# 19190  Friendly staff, good bar food and great drank ...
# 19191  I have been here twice on a Monday afternoon a...
# 19192  Food: Ordered a Prime Rib Sandwich, and by no ...
# 19193  I've had a mix of experiences here but one thi...
# 19194   A good place to eat and drink likely on the w...
# 19195  Decent food and service, but I can honestly sa...
# 19196
# 19197  Over the course of a week, there comes a time ...
# 19198   But please, indulge in the quesadillas, tiny ...
# 19199  Great place for eating and enjoying some reall...
# 19200  In general, I like Guidos.\n  I think their fo...
# 19201   If friends suggest Guido's, which they often ...
# 19202  The food is very good, but I've been to lunch ...
# 19203  I like their decor, and I like their onion rin...
# 19204   Of course many other reviewers make good poin...
# 19205  This is not a place to write home about for th...
# 19206  What comes to mind when I think of Guido's? Th...
# 19207  Outstanding food for the price, but the staff ...
# 19208                       Food just never up to par.\n
# 19209  Very disappointing tonight.\n I know it's pub ...
# 19210  Had a grilled ham & cheese sandwich that was g...
# 19211
# 19212  Guido's is ok.\nPros: great burgers (even the ...
# 19213
# 19214   It's great for our friends and my wife becaus...
# 19215  The burgers are good! They claim double patty ...
# 19216  It did have one good experience, but last nigh...
# 19217  The food is fantastic for the price, especiall...
# 19218   We had a wonderful dinner.\n It is basic bar ...
# 19219    But a hamburger order plus 3 club sandwiches...
#
#                                                  service  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6       It was a weeknight so luckily there was no li...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15     Come here when it's busy, and you won't be dis...
# 16     im sorry but who wants to be waited on as soon...
# 17      You have to chase down a server to get a drin...
# 18
# 19
# 20                    We never got a refill on drinks.\n
# 21
# 22
# 23
# 24                                    very poor shape.\n
# 25
# 26
# 27
# 28
# 29     Walked in, not greeted, was asked "How many" a...
# ...                                                  ...
# 19190                            Can spend hours here.\n
# 19191
# 19192   She refilled my water, made sure my food came...
# 19193
# 19194
# 19195
# 19196
# 19197  I am the type of person that usually is able t...
# 19198   I have not come to this restaurant and sat up...
# 19199
# 19200
# 19201   The place gets pretty crowded on Thurs-Sat ni...
# 19202    Slow service, screwed up orders, slow to get...
# 19203    It seriously took 10 minutes between being s...
# 19204
# 19205
# 19206                      But seriously - who cares?.\n
# 19207
# 19208
# 19209
# 19210
# 19211            very dishonest, questionable service.\n
# 19212  sides (ESP fruit and veges) on sandwiches not ...
# 19213
# 19214
# 19215   If you want decent service, make sure to be a...
# 19216
# 19217  I go to Guido's occasionally and always have a...
# 19218                   And the service was very good.\n
# 19219    A projected 60 minute wait lasted 40.\n  Had...
#
#                                                    staff  \
# 0       This restaurant should really be inspected by...
# 1       I alerted a waitress, who acted as if it was ...
# 2
# 3       You would think the staff would pick up trash...
# 4
# 5
# 6       Even the water that they were boiled in looke...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14      The manager is also extremely unprofessional ...
# 15
# 16
# 17      Makes me wonder if the employees ever wash th...
# 18
# 19                       Horrible, slam dunk horrible.\n
# 20
# 21
# 22      Our waitress was very sweet as well.\n We did...
# 23
# 24
# 25
# 26
# 27
# 28     Rude came in8:45 close at 9 told us we could e...
# 29     Short answer: Avoid this place.\n Waitress did...
# ...                                                  ...
# 19190
# 19191
# 19192   I'd guess it was a cut of ribeye, but it was ...
# 19193
# 19194
# 19195
# 19196   Yea thanks already knew that.\n Offered no ap...
# 19197
# 19198  The bartenders are always very friendly and ni...
# 19199
# 19200  The bartenders have always been very nice, but...
# 19201
# 19202                  everybody, management included.\n
# 19203    It was one of those non-busy times when ther...
# 19204
# 19205
# 19206                                    End of story.\n
# 19207
# 19208
# 19209
# 19210
# 19211   Was charged for 16 drinks - asked to speak wi...
# 19212
# 19213
# 19214
# 19215
# 19216   We sat and stared in their direction and noth...
# 19217
# 19218
# 19219                        Wait staff was oblivious.\n
#
#                                                 location  \
# 0
# 1       I will be calling the Champaign-Urbana Public...
# 2
# 3
# 4      I was visiting the Champaign area with my fami...
# 5
# 6      Another restaurants make the DNV list in Champ...
# 7      They have a wide range of things to eat and th...
# 8
# 9
# 10                       STAY AWAY OF THIS PLACE!!!!!.\n
# 11
# 12
# 13      Looks run down from the outside.\n Would reco...
# 14
# 15
# 16
# 17
# 18
# 19      Over the last four years, I went to this rest...
# 20      They could cut in front of you and stand righ...
# 21       Oh, and I do like "fried biscuits" the donut...
# 22
# 23
# 24      The outside needs attention, and the restroom...
# 25
# 26     Not the best Chinese in town, but I think my p...
# 27
# 28
# 29      The Chinese restaurant life has been my famil...
# ...                                                  ...
# 19190   Awesome patio, especially for solar eclipses....
# 19191   But, I also got a ticket while parked in the ...
# 19192  Ambiance: Guido's seems to be more of a sports...
# 19193   And there's ample seating! One of my downtown...
# 19194  An overall pretty good bar in downtown Champai...
# 19195
# 19196
# 19197   We typically go for our favorite restaurants ...
# 19198  This is a bar that i have been to a lot of net...
# 19199
# 19200  Overall, I like going there to play pool on th...
# 19201  There are a million places just like Guido's o...
# 19202
# 19203
# 19204  If you are in the mood for nachos, head here.\...
# 19205    Obviously I could only remember the ones tha...
# 19206
# 19207                        Best onion rings in town.\n
# 19208   Walk across the street to try something else....
# 19209   Grateful that we have plenty of better option...
# 19210   Sat at the bar and service was pretty poor co...
# 19211
# 19212  Cons: Downstairs club gets a bit rough later o...
# 19213   The hand written letter is most impressive of...
# 19214  I keep coming back over and over for a good dr...
# 19215
# 19216   Entered, sat down to eat.\n A bar tender and ...
# 19217  During the day it has a nice, laid-back atmosp...
# 19218
# 19219                             A bar with bar food.\n
#
#                                                    value
# 0      I would have given this restaurant zero stars ...
# 1
# 2
# 3       The quality ranges from poor to mediocre.\n I...
# 4
# 5       this is by far the worst sushi I have ever se...
# 6      Restaurant review:.\n This is bad news.\n Okay...
# 7      I was looking for reviews and I saw how bad th...
# 8
# 9       Price was ok.\n Everything is just within the...
# 10     The worst buffet I've ever had.\n Not worth of...
# 11
# 12
# 13            Nothing really special about this place.\n
# 14      I just can't shake the substandard health sta...
# 15
# 16     so heres a tip if your reading this yall bette...
# 17      I use to really like this place but over the ...
# 18
# 19      This was definitely the worst among all.\n Ea...
# 20
# 21
# 22      However, we brought a coupon that we printed ...
# 23      There's plenty of seating here and you genera...
# 24
# 25     It's my favorite place to eat other then the f...
# 26      Therefore, I appreciate the decent selection ...
# 27
# 28
# 29     Not trying to tear down this restaurant becaus...
# ...                                                  ...
# 19190
# 19191   However, I am not that impressed with anythin...
# 19192
# 19193
# 19194
# 19195   In fact, I only go here when the rest of the ...
# 19196  Owner reached out to me after I wrote this rev...
# 19197
# 19198
# 19199     Almost forgot to speak of their milk shakes.\n
# 19200    They have a good selection of bottled beer, ...
# 19201  Going a few more times since last review, I th...
# 19202
# 19203  Other than that, I was just not impressed.\n  ...
# 19204
# 19205    I dont remember them all but Tuesdays are 4 ...
# 19206
# 19207
# 19208
# 19209   I wouldn't even have minded this if we had be...
# 19210
# 19211  Do not open a tab here.\n I came in two days l...
# 19212
# 19213  I am very impressed.\n With a coupon and a han...
# 19214  They do both very well and at a reasonable pri...
# 19215
# 19216   The only reason I am giving it one star is be...
# 19217
# 19218  The management went out of their way to make u...
# 19219
#
# [19220 rows x 8 columns]

# %%
aspects_df.to_csv('processed_data/aspect_review.csv',encoding='utf-8')

# %%
assign_aspect('A bar with bar food. There were four of us.',aspect_map)
# Out:
# {'atmosphere': 0.5312161445617676, 'area': 0.8184992074966431, 'bartender': 1.1844112873077393, 'food': 1.0}
# 'staff'

# %%
senti_model.wv.similarity(w1='bar',w2='food')
# Out:
# -0.030885737

# %%
#END
